# %% [markdown]
# <a href="https://colab.research.google.com/github/maheshboj/agenticai_basics/blob/main/RAG_CHAT_BOT_EVALUATION_DEC2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Install dependencies

# %%
# %pip install -qU langchain langchain-community langchain-openai langchain-chroma pypdf
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 4.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 38.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 7.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.0/331.0 kB 22.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.5/21.5 MB 43.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 50.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 5.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 20.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 78.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 71.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 4.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.6/132.6 kB 11.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 5.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.0/220.0 kB 13.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 8.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 kB 5.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 4.6 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.5 which is incompatible.
# opentelemetry-exporter-gcp-logging 1.11.0a0 requires opentelemetry-sdk<1.39.0,>=1.35.0, but you have opentelemetry-sdk 1.39.1 which is incompatible.
# opentelemetry-exporter-otlp-proto-http 1.38.0 requires opentelemetry-exporter-otlp-proto-common==1.38.0, but you have opentelemetry-exporter-otlp-proto-common 1.39.1 which is incompatible.
# opentelemetry-exporter-otlp-proto-http 1.38.0 requires opentelemetry-proto==1.38.0, but you have opentelemetry-proto 1.39.1 which is incompatible.
# opentelemetry-exporter-otlp-proto-http 1.38.0 requires opentelemetry-sdk~=1.38.0, but you have opentelemetry-sdk 1.39.1 which is incompatible.

# %%
# %pip install -qU "unstructured[all-docs]"
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 16.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.1/68.1 kB 4.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.7/107.7 kB 6.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 608.4/608.4 kB 33.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 538.2/538.2 kB 32.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.8/48.8 kB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 46.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 100.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 68.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 85.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.6/155.6 kB 10.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.0/34.0 MB 28.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.0/253.0 kB 15.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.8/167.8 kB 7.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 472.8/472.8 kB 28.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 86.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.2/220.2 kB 16.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 3.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.0/88.0 kB 6.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 66.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.6/114.6 kB 9.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 80.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.3/175.3 kB 11.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.5/17.5 MB 83.5 MB/s eta 0:00:00
#   Building wheel for langdetect (setup.py) ... done

# %%
# %pip install -qU langsmith
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 324.3/324.3 kB 7.0 MB/s eta 0:00:00

# %%
from google.colab import userdata

# %% [markdown]
# #Environment variables

# %%
import os
os.environ["OPENAI_API_KEY"] = userdata.get('OPENAI_APIKEY')
os.environ["LANGSMITH_API_KEY"] = userdata.get('LANGSMITH_API')
os.environ["LANGSMITH_TRACING"] = "true"
os.environ["LANGSMITH_PROJECT"] = "langsmith_rag_eval_dec2025"

# %% [markdown]
# # 2. Load documents (PDF example)

# %%
from langchain_community.document_loaders import TextLoader
from langchain_community.document_loaders import PyPDFLoader
loader = TextLoader("/content/Tech_Mahindra_Report_original.md")
doc = loader.load()

# %%
from langchain_community.document_loaders import UnstructuredMarkdownLoader

loader = UnstructuredMarkdownLoader("/content/Tech_Mahindra_Report_original.md", mode="elements")
docs = loader.load()

# %%
len(docs)
# Out:
# 162

# %% [markdown]
# # 3. Split into chunks

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,      # Character chunks
    chunk_overlap=200,    # Overlap for context
    add_start_index=True  # Track source location
)
splits = text_splitter.split_documents(docs)
print(f"Split into {len(splits)} chunks")
# Out:
# Split into 162 chunks

# %% [markdown]
# # 4. Embeddings & Vector Store (Chroma - local, persistent)

# %%
from langchain_openai import OpenAIEmbeddings
from langchain_chroma import Chroma
from langchain_community.vectorstores.utils import filter_complex_metadata

embeddings = OpenAIEmbeddings(model="text-embedding-3-small")  # Fast/cheap embeddings

# Filter complex metadata before creating the vectorstore
filtered_splits = filter_complex_metadata(splits)

vectorstore = Chroma.from_documents(
    documents=filtered_splits,
    embedding=embeddings,
    persist_directory="./techm_db"  # Saves locally
)

# %% [markdown]
# # 5. Create retriever (k=4 most relevant docs)

# %%
retriever = vectorstore.as_retriever(search_kwargs={"k": 4})

# %% [markdown]
# # 6. RAG Chain: Retrieve → Prompt → LLM → Parse

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI
from langchain_core.runnables import RunnablePassthrough,RunnableParallel
from langchain_core.output_parsers import StrOutputParser
from langsmith import traceable
llm = ChatOpenAI(model="gpt-4.1", temperature=0)

prompt = ChatPromptTemplate.from_template("""
Answer the question based ONLY on the provided context.
If you can't answer from context, say "I don't have enough information."

Context: {context}

Question: {question}
Answer:
""")

# Chain: docs → text → prompt → LLM → string
@traceable(run_type="chain")
def call_rag_chain(question: str) -> str:
  rag_chain = (
          RunnableParallel({
          "context": retriever,
          "question": RunnablePassthrough()
      }) # Input → retrieve + pass-through
      | prompt
      | llm
      | StrOutputParser()
  )
  answer = rag_chain.invoke(question)
  print(f"Q: {question}\nA: {answer}")
  return answer

# %%
# Test it!
question = "give me details of work from home policy or WFH ?"
call_rag_chain(question)
# Out:
# Q: give me details of work from home policy or WFH ?
# A: The work-from-home (WFH) policy includes flexible work-from-home arrangements that ensure work continuity and employee safety. It supports work-life balance and productivity, and is particularly utilized for pandemic resilience.
# 'The work-from-home (WFH) policy includes flexible work-from-home arrangements that ensure work continuity and employee safety. It supports work-life balance and productivity, and is particularly utilized for pandemic resilience.'

# %%
import uuid
thread_id = uuid.uuid4()

# %%
thread_id
# Out:
# UUID('b4105872-590a-4b0b-970a-3dd21bd22d14')

# %%
# 7. Test the bot!
question = ""
answer = call_rag_chain(question)
# Interactive chat loop
while True:
    query = input("\nAsk a question (or 'quit'): ")
    if query.lower() == 'quit':
        break
    print(f"A: {call_rag_chain(query,langsmith_extra={"metadata": {"thread_id": thread_id}})}")
# Out:
# Q:
# A: I don't have enough information.
#
# Ask a question (or 'quit'): how many leaves do we have?
# Q: how many leaves do we have?
# A: Based on the provided context, the total minimum Paid Time Off (PTO) is approximately 35-40+ days per year (excluding compensatory off and extensions). This includes:
#
# - Earned/Annual Leave: 21 days
# - Advance Leave: 5 days (adjusted against earned leave)
# - Public Holidays: 9 days (varies by location)
# - Optional Holiday: 1 day (self-selected)
# - Maternity Leave: 90 days paid + up to 6 months extended (females only)
# - Paternity Leave: 2 days (males)
# - Comp Off: Flexible (if worked on holidays)
#
# So, the minimum is about 35-40+ days per year, not counting comp off and maternity/paternity leave extensions.
# A: Based on the provided context, the total minimum Paid Time Off (PTO) is approximately 35-40+ days per year (excluding compensatory off and extensions). This includes:
#
# - Earned/Annual Leave: 21 days
# - Advance Leave: 5 days (adjusted against earned leave)
# - Public Holidays: 9 days (varies by location)
# - Optional Holiday: 1 day (self-selected)
# - Maternity Leave: 90 days paid + up to 6 months extended (females only)
# - Paternity Leave: 2 days (males)
# - Comp Off: Flexible (if worked on holidays)
#
# So, the minimum is about 35-40+ days per year, not counting comp off and maternity/paternity leave extensions.
#
# Ask a question (or 'quit'): how many leaves i can carry forward
# Q: how many leaves i can carry forward
# A: Maximum 16 days can be carried to next calendar year.
# A: Maximum 16 days can be carried to next calendar year.
#
# Ask a question (or 'quit'): quit

# %% [markdown]
# # Generate Questions Automatically from the chunks

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import StrOutputParser

# 2. Define a ChatPromptTemplate named question_gen_prompt
question_gen_prompt = ChatPromptTemplate.from_template("""
Generate a single question that can be answered SOLELY from the following context.

Context: {context}

Question:
""")

# 3. Initialize a ChatOpenAI model for generating questions
question_gen_llm = ChatOpenAI(model="gpt-4.1", temperature=0)

# 4. Create an LLM chain named question_gen_chain
question_gen_chain = (
    {"context": lambda x: x}
    | question_gen_prompt
    | question_gen_llm
    | StrOutputParser()
)

# 5. Initialize an empty list called generated_questions
generated_questions = []

# 6. Iterate through each split and generate a question
for i, split in enumerate(splits):
    question = question_gen_chain.invoke(split.page_content)
    generated_questions.append(question)
    print(f"Generated question for chunk {i+1}: {question}")

print(f"\nTotal {len(generated_questions)} questions generated.")
# Out:
# Generated question for chunk 1: Question: According to the Tech Mahindra: Comprehensive Report, what is the main focus area of Tech Mahindra's business operations?
# Generated question for chunk 2: What are the three topics covered in the context: Leave Policy, Employee Count, and AI Strategy?
# Generated question for chunk 3: What information does Tech Mahindra Limited’s December 2025 report provide regarding its HR policies, workforce metrics, and strategic AI direction?
# Generated question for chunk 4: What is the main purpose of the Executive Summary?
# Generated question for chunk 5: What is the total number of professionals employed by Tech Mahindra according to the report?
# Generated question for chunk 6: What types of leave and work-life balance initiatives are included in the company's HR policies?
# Generated question for chunk 7: What information does the context provide about the current number of employees, past workforce trends, and employee attrition rates?
# Generated question for chunk 8: What is the name of the initiative mentioned in the AI Strategy & Future Roadmap that focuses on delivering AI effectively?
# Generated question for chunk 9: What section of the document contains information about leave policy and employee benefits?
# Generated question for chunk 10: What type of leave is described in section 1.1?
# Generated question for chunk 11: How many earned leave days can an employee carry forward to the next calendar year?
# Generated question for chunk 12: What is the topic discussed in section 1.2?
# Generated question for chunk 13: How many days of advance leave are available, and how is advance leave adjusted?
# Generated question for chunk 14: What is Tech Mahindra's formal policy on casual leave?
# Generated question for chunk 15: When is an employee eligible for Compensatory Off (Comp Off)?
# Generated question for chunk 16: What are the two options available to an employee who has exhausted their leave balance according to the context?
# Generated question for chunk 17: How many optional holidays can an employee take per year without needing manager approval?
# Generated question for chunk 18: What is the topic discussed in section 1.3?
# Generated question for chunk 19: What is the maximum duration a new mother at Tech Mahindra can take paid maternity leave before needing to use earned leaves or leave without pay?
# Generated question for chunk 20: According to the context, what is the duration of paternity leave and is it available globally?
# Generated question for chunk 21: What is the section number that discusses Additional Leave Benefits?
# Generated question for chunk 22: What types of reasons are sabbatical leaves available for, according to the policy?
# Generated question for chunk 23: How do flexible work-from-home arrangements support work continuity and employee safety, especially during a pandemic?
# Generated question for chunk 24: What is the purpose of the flexible work arrangements mentioned in the context?
# Generated question for chunk 25: According to the context, what type of leave entitlements are summarized annually?
# Generated question for chunk 26: According to the context, how many days of paid maternity leave are provided, and who is eligible for it?
# Generated question for chunk 27: How many employees are included in the workforce metrics described in Section 2?
# Generated question for chunk 28: What is the time reference for the current workforce data provided in section 2.1?
# Generated question for chunk 29: What was the total headcount of employees as of September 30, 2025?
# Generated question for chunk 30: What does section 2.2 focus on regarding workforce trends?
# Generated question for chunk 31: What was the year-over-year percentage change in headcount as of March 31, 2025?
# Generated question for chunk 32: What is the title of section 2.3 in the provided context?
# Generated question for chunk 33: In which quarter did the company experience a sequential growth in headcount after two consecutive quarters of decline?
# Generated question for chunk 34: Question: According to section 2.4, what trends are observed in IT headcount?
# Generated question for chunk 35: What was the quarter-over-quarter change in IT headcount from Q4 FY'25 to Q2 FY'26?
# Generated question for chunk 36: What does the slight year-over-year decline in IT headcount suggest according to the commentary?
# Generated question for chunk 37: What is the topic discussed in section 2.5?
# Generated question for chunk 38: What was the attrition rate trend from Q4 FY'25 to Q2 FY'26?
# Generated question for chunk 39: What is the current attrition rate, and how does it compare to the industry acceptable range?
# Generated question for chunk 40: What is the main topic discussed in section 2.6?
# Generated question for chunk 41: What is the approximate profit per employee according to the provided data?
# Generated question for chunk 42: What is the main topic discussed in section 2.7?
# Generated question for chunk 43: In how many countries does the organization have a presence?
# Generated question for chunk 44: Where are the majority of the 150,000+ professionals in the India Workforce based?
# Generated question for chunk 45: Which regions are listed as Global Centers in the provided context?
# Generated question for chunk 46: Which service lines are included in the context?
# Generated question for chunk 47: What is the main focus of Section 3 in relation to AI?
# Generated question for chunk 48: What is the name of the strategic initiative described in section 3.1?
# Generated question for chunk 49: What is the name of the comprehensive AI strategy launched by Tech Mahindra in April 2025 to promote responsible, practical, and scalable adoption of AI across industries?
# Generated question for chunk 50: What is the vision statement?
# Generated question for chunk 51: What are the key elements needed to ensure AI delivers real-world impact according to the context?
# Generated question for chunk 52: Who is the CEO and MD of Tech Mahindra?
# Generated question for chunk 53: What is the main topic discussed in section 3.2?
# Generated question for chunk 54: What is the phrase mentioned in the context?
# Generated question for chunk 55: What is being integrated into the core of enterprise processes according to the context?
# Generated question for chunk 56: What is being unlocked according to the context?
# Generated question for chunk 57: What is the focus of legacy system modernization in the context provided?
# Generated question for chunk 58: What is the main focus of process optimization as described in the context?
# Generated question for chunk 59: What is the title of section 2 in the provided context?
# Generated question for chunk 60: What is being accelerated across operations according to the context?
# Generated question for chunk 61: What two key concepts are discussed in the context: intelligent automation and smart decisioning?
# Generated question for chunk 62: What is the focus of optimized spending according to the context?
# Generated question for chunk 63: What are the primary areas of focus mentioned in the context?
# Generated question for chunk 64: What is the title of section 3 in the provided context?
# Generated question for chunk 65: What does the context mention as being enabled?
# Generated question for chunk 66: What is the technology that enables the system to be powered by advanced capabilities?
# Generated question for chunk 67: What is the main focus of the context provided?
# Generated question for chunk 68: How does the context emphasize the importance of competitive differentiation and market expansion?
# Generated question for chunk 69: Question: What is the title of section 4 in the provided context?
# Generated question for chunk 70: How does the context suggest organizations should approach each deployment?
# Generated question for chunk 71: What are responsible AI practices and frameworks designed to address?
# Generated question for chunk 72: What are the processes involved in ensuring the accuracy and reliability of AI outcomes?
# Generated question for chunk 73: What are the primary areas emphasized in the context of Ethical AI, compliance, and risk mitigation?
# Generated question for chunk 74: What is the main focus of section 3.3 in the provided context?
# Generated question for chunk 75: What is the name of India's first foundational Large Language Model (LLM) that was developed in collaboration with Intel Corporation and open-sourced for broader industry adoption?
# Generated question for chunk 76: What is the primary focus area of Agentic AI systems as described in the context?
# Generated question for chunk 77: What is the primary purpose of the VerifAI Framework in AI projects?
# Generated question for chunk 78: What trio of digital technologies does InfinityOps Solutions' ZeroOps offering help clients harness to address complex business and IT operations challenges?
# Generated question for chunk 79: What recent example demonstrates the tangible production results and industry-specific commitment of an Agentic AI pharmacovigilance solution?
# Generated question for chunk 80: Question: What is the title of section 3.4?
# Generated question for chunk 81: Which sectors does Tech Mahindra's AI strategy focus on for significant AI-driven transformation?
# Generated question for chunk 82: Which industry is identified as a digital transformation leader due to its use of AI for predictive maintenance, supply chain, and quality?
# Generated question for chunk 83: What is the focus of section 3.5 in relation to workforce skills and artificial intelligence?
# Generated question for chunk 84: By when does the Workforce Upskilling Initiative aim to train the entire workforce on AI fundamentals and responsible AI use?
# Generated question for chunk 85: What is the main focus of section 3.6?
# Generated question for chunk 86: Which company collaborated on Project Indus and AI model deployment as part of strategic partnerships?
# Generated question for chunk 87: What does a curated AI partner ecosystem provide to ensure optimal AI deployment across customer segments?
# Generated question for chunk 88: What is the title of section 3.7?
# Generated question for chunk 89: What title was awarded in 2024 to demonstrate credibility and market leadership in enterprise AI according to Avasant?
# Generated question for chunk 90: What types of services are included under the 3.8 AI Service Offerings?
# Generated question for chunk 91: What type of services does Tech Mahindra provide according to the context?
# Generated question for chunk 92: What is the primary focus of AI Strategy & Consultation?
# Generated question for chunk 93: What two key activities are involved in the process described in the context?
# Generated question for chunk 94: What is the primary focus of an AI maturity assessment?
# Generated question for chunk 95: What factors should be considered when evaluating an enterprise AI architecture?
# Generated question for chunk 96: What is the main topic discussed in the context?
# Generated question for chunk 97: What are the two main phases described in the context?
# Generated question for chunk 98: What is the main focus of the context provided?
# Generated question for chunk 99: What is the primary focus of legacy system modernization?
# Generated question for chunk 100: What is the main focus of Responsible AI?
# Generated question for chunk 101: What is the main subject discussed in the context provided?
# Generated question for chunk 102: What are risk mitigation strategies?
# Generated question for chunk 103: What two key areas are addressed by compliance and ethical AI practices?
# Generated question for chunk 104: What is the main subject discussed in the context?
# Generated question for chunk 105: What is the main focus of autonomous decision-making workflows?
# Generated question for chunk 106: What type of platforms are discussed in the context?
# Generated question for chunk 107: What type of automation is described as "business-critical"?
# Generated question for chunk 108: What section of the document discusses the organization's plans and potential areas for growth?
# Generated question for chunk 109: What is the time frame covered by the short-term focus mentioned in section 4.1?
# Generated question for chunk 110: By what year is the company expecting to have trained over 150,000 employees in AI reskilling?
# Generated question for chunk 111: What is the time frame covered by the Medium-term Strategy described in section 4.2?
# Generated question for chunk 112: What is the targeted percentage increase for AI services revenue?
# Generated question for chunk 113: What is the target number of AI/ML specialists to be built for the talent bench?
# Generated question for chunk 114: How many production agentic AI systems are to be deployed according to the context?
# Generated question for chunk 115: What is the target number of AI-enabled customers to expand to?
# Generated question for chunk 116: What is the time frame covered by the long-term vision described in section 4.3?
# Generated question for chunk 117: What is the focus of an AI-First Organization when transitioning to a new business model?
# Generated question for chunk 118: What is the goal regarding industry leadership mentioned in the context?
# Generated question for chunk 119: What percentage of internal processes are AI-driven in autonomous workflows?
# Generated question for chunk 120: What is the focus of building proprietary AI frameworks and solutions in relation to Project Indus?
# Generated question for chunk 121: What is the main focus of section 4.4?
# Generated question for chunk 122: According to the context, what should be prioritized before speed in the development of AI?
# Generated question for chunk 123: Question: According to the context, which type of solutions—verticals or horizontal—are emphasized in industry-specific solutions?
# Generated question for chunk 124: According to the context, what type of AI systems are emphasized: autonomous systems or chatbots?
# Generated question for chunk 125: What approach does the "Ecosystem Play" emphasize compared to a build-only model?
# Generated question for chunk 126: What mindset is emphasized across the organization according to the context?
# Generated question for chunk 127: What topics are discussed in Section 5?
# Generated question for chunk 128: What section discusses the present difficulties being faced?
# Generated question for chunk 129: What was the year-over-year change in the attrition rate, and what does this indicate about competitive pressure in the industry?
# Generated question for chunk 130: Which companies are identified as major competitors in the context of rising AI talent costs and skills shortages in emerging AI domains?
# Generated question for chunk 131: How are extended proof-of-concept (PoC) phases affecting revenue realization in a business environment characterized by client budget constraints and cautious IT spending?
# Generated question for chunk 132: Question: What is the section number and title that discusses strategic opportunities?
# Generated question for chunk 133: What is the expected compound annual growth rate (CAGR) of the global GenAI market through 2030?
# Generated question for chunk 134: Which industries are identified as ready for AI-driven transformation and large contract opportunities in legacy system modernization?
# Generated question for chunk 135: What are the key initiatives mentioned for advancing the Talent & Ecosystem strategy?
# Generated question for chunk 136: According to the context, in which regions is there a plan to expand AI services?
# Generated question for chunk 137: What are the main points summarized in Section 6: Key Takeaways?
# Generated question for chunk 138: Who is the intended audience described in the context?
# Generated question for chunk 139: What career growth opportunity related to AI is planned to be available by March 2026?
# Generated question for chunk 140: Who is the intended audience described in the context?
# Generated question for chunk 141: What aspect of the company's approach is intended to reduce execution risk according to the context?
# Generated question for chunk 142: Who is the intended audience described in the context?
# Generated question for chunk 143: Which service mentioned in the context focuses on localization needs specific to India?
# Generated question for chunk 144: What type of information is provided in Section 7?
# Generated question for chunk 145: Question: Which company is being referred to in the provided context?
# Generated question for chunk 146: According to the context, how many Proofs of Concept (PoCs) are planned to be moved to production as part of accelerating Agentic AI monetization?
# Generated question for chunk 147: What is being developed to deepen industry specialization according to the context?
# Generated question for chunk 148: What strategy is suggested for building an AI talent pipeline according to the context?
# Generated question for chunk 149: What role does Tech Mahindra aim to establish in the AI partner ecosystem according to the context?
# Generated question for chunk 150: What internal AI tools are being used to make the organization a case study for responsible AI?
# Generated question for chunk 151: What information is provided in the context specifically for individuals seeking employment?
# Generated question for chunk 152: What fields does the opportunity specifically mention as areas of interest?
# Generated question for chunk 153: By when is mandatory AI reskilling required to guarantee career growth?
# Generated question for chunk 154: What supports work-life balance according to the context?
# Generated question for chunk 155: How does the context describe the reach of cutting-edge AI across different industries?
# Generated question for chunk 156: What section of the document provides information about where the data was obtained and the references used?
# Generated question for chunk 157: On what date did Tech Mahindra release its Q2 FY'26 results, according to the provided context?
# Generated question for chunk 158: What type of information is provided in the "Contact & Further Information" section?
# Generated question for chunk 159: What is the stock symbol for Tech Mahindra Limited?
# Generated question for chunk 160: Where can you find information about Tech Mahindra's AI services and updates on Project Indus?
# Generated question for chunk 161: As of which quarter and fiscal year does the current data in the report extend?
# Generated question for chunk 162: What sources of information were used to prepare this report?
#
# Total 162 questions generated.

# %% [markdown]
# **Reasoning**:
# The next step is to iterate through the `generated_questions` and use the `call_rag_chain` function to find answers for each question. The questions and their answers will then be compiled into `document_qa_pairs`.

# %%
sample_generated_questions = []

for i, split in enumerate(splits[:10]):
    question = question_gen_chain.invoke(split.page_content)
    sample_generated_questions.append(question)
    print(f"Generated question for chunk {i+1}: {question}")

print(f"\nTotal {len(sample_generated_questions)} sample questions generated.")
# Out:
# Generated question for chunk 1: What is the title of the report discussed in the context?
# Generated question for chunk 2: What are the three topics covered in the context provided?
# Generated question for chunk 3: What is the focus of Tech Mahindra Limited's report dated December 2025?
# Generated question for chunk 4: What is the main purpose of the Executive Summary?
# Generated question for chunk 5: What is the number of professionals employed by Tech Mahindra, as mentioned in the report?
# Generated question for chunk 6: What types of leave and work-life balance initiatives are included in the company's HR policies?
# Generated question for chunk 7: What information does the context provide about current headcount, historical trends, and attrition rates?
# Generated question for chunk 8: What is the name of the initiative mentioned in the AI Strategy & Future Roadmap that focuses on delivering AI effectively?
# Generated question for chunk 9: What section of the document contains information about leave policy and employee benefits?
# Generated question for chunk 10: What type of leave is described in section 1.1?
#
# Total 10 sample questions generated.

# %%
sample_qa_pairs = []
inputs=[]
outputs=[]

for question in sample_generated_questions:
    # Use the existing call_rag_chain function to get the answer
    answer = call_rag_chain(question)
    inputs.append({"question": question})
    outputs.append({"output": answer})
# Out:
# Q: What is the title of the report discussed in the context?
# A: The title of the report discussed in the context is "Tech Mahindra: Comprehensive Report".
# Q: What are the three topics covered in the context provided?
# A: The three topics covered in the context provided are:
#
# 1. Industry Focus Areas
# 2. Key AI Technologies & Frameworks
# 3. Challenges & Opportunities
# Q: What is the focus of Tech Mahindra Limited's report dated December 2025?
# A: The focus of Tech Mahindra Limited's report dated December 2025 is HR Policies, Workforce Metrics, and Strategic AI Direction.
# Q: What is the main purpose of the Executive Summary?
# A: I don't have enough information.
# Q: What is the number of professionals employed by Tech Mahindra, as mentioned in the report?
# A: The report mentions that Tech Mahindra employs 150,000+ professionals.
# Q: What types of leave and work-life balance initiatives are included in the company's HR policies?
# A: The company's HR policies include a comprehensive leave policy with 35-40+ days of annual paid time off (PTO), excellent maternity and paternity benefits with 90+ days of paid leave, and work-life balance initiatives supported through flexible work arrangements.
# Q: What information does the context provide about current headcount, historical trends, and attrition rates?
# A: The context provides that there is information on current headcount, historical trends, and attrition rates. Specifically, it states that attrition has gradually increased from approximately 11% to 12.8%, reflecting competitive market conditions and employee mobility, but this rate is still within the industry acceptable range of 10-15%. However, the exact current headcount and detailed historical trends are not specified in the provided context.
# Q: What is the name of the initiative mentioned in the AI Strategy & Future Roadmap that focuses on delivering AI effectively?
# A: The name of the initiative is "AI Delivered Right."
# Q: What section of the document contains information about leave policy and employee benefits?
# A: Section 1: Leave Policy & Employee Benefits
# Q: What type of leave is described in section 1.1?
# A: The type of leave described in section 1.1 is Earned Leave (Annual Leave).

# %%
inputs
# Out:
# [{'question': 'What is the title of the report discussed in the context?'},
#  {'question': 'What are the three topics covered in the context provided?'},
#  {'question': "What is the focus of Tech Mahindra Limited's report dated December 2025?"},
#  {'question': 'What is the main purpose of the Executive Summary?'},
#  {'question': 'What is the number of professionals employed by Tech Mahindra, as mentioned in the report?'},
#  {'question': "What types of leave and work-life balance initiatives are included in the company's HR policies?"},
#  {'question': 'What information does the context provide about current headcount, historical trends, and attrition rates?'},
#  {'question': 'What is the name of the initiative mentioned in the AI Strategy & Future Roadmap that focuses on delivering AI effectively?'},
#  {'question': 'What section of the document contains information about leave policy and employee benefits?'},
#  {'question': 'What type of leave is described in section 1.1?'}]

# %%
outputs
# Out:
# [{'output': 'The title of the report discussed in the context is "Tech Mahindra: Comprehensive Report".'},
#  {'output': 'The three topics covered in the context provided are:\n\n1. Industry Focus Areas\n2. Key AI Technologies & Frameworks\n3. Challenges & Opportunities'},
#  {'output': "The focus of Tech Mahindra Limited's report dated December 2025 is HR Policies, Workforce Metrics, and Strategic AI Direction."},
#  {'output': "I don't have enough information."},
#  {'output': 'The report mentions that Tech Mahindra employs 150,000+ professionals.'},
#  {'output': "The company's HR policies include a comprehensive leave policy with 35-40+ days of annual paid time off (PTO), excellent maternity and paternity benefits with 90+ days of paid leave, and work-life balance initiatives supported through flexible work arrangements."},
#  {'output': 'The context provides that there is information on current headcount, historical trends, and attrition rates. Specifically, it states that attrition has gradually increased from approximately 11% to 12.8%, reflecting competitive market conditions and employee mobility, but this rate is still within the industry acceptable range of 10-15%. However, the exact current headcount and detailed historical trends are not specified in the provided context.'},
#  {'output': 'The name of the initiative is "AI Delivered Right."'},
#  {'output': 'Section 1: Leave Policy & Employee Benefits'},
#  {'output': 'The type of leave described in section 1.1 is Earned Leave (Annual Leave).'}]

# %%
from langsmith import Client

client = Client()
# TODO: Fill in dataset id
dataset_id = "5b2bdb15-bd58-4db6-8c63-381a9f034a91"

client.create_examples(
  inputs=inputs,
  outputs=outputs,
  dataset_id=dataset_id,
)
# Out:
# {'example_ids': ['c27aa9c7-bfb7-4969-aedb-fc8a1b2023d6',
#   '9782e5ef-4df8-4042-b1ff-ef6c84acb601',
#   '906615e4-1495-485b-95bf-2ac68fa9c62d',
#   'caf632ed-a8eb-47e1-975a-95e92fbd8b67',
#   '9cde8c33-fbcb-4078-a5cd-09055a3bb7a0',
#   '79d2e644-812a-494d-8be9-58b0fed1ae7b',
#   '5875bfc8-518c-4c69-8106-88ffb30da500',
#   '76ff6140-b023-45b4-b1f8-7986482bf2e8',
#   'd76a7301-0d24-4ebe-8016-8f7acc13c53e',
#   'ecbf4b3d-35d1-452b-86d5-8a1f4e0ad96e'],
#  'count': 10,
#  'as_of': '2026-02-20T04:51:13.411308809Z'}

# %% [markdown]
# # LLM as a Judge Evaluator

# %%
from langchain.agents import create_agent
from langchain.agents.structured_output import ToolStrategy

# %%
eval_prompt="""You are a semantic similarity evaluator. Compare the meanings of two responses to a question, "
                    "Reference Response and New Response, where the reference is the correct answer, and we are trying to judge if the new response is similar. "
                    "Provide a score between 1 and 10, where 1 means completely unrelated, and 10 means identical in meaning."""

# %%
from pydantic import BaseModel, Field
class Similarity_Score(BaseModel):
    similarity_score: int = Field(description="Semantic similarity score between 1 and 10, where 1 means unrelated and 10 means identical.")

# %%
agent= create_agent(
    model="gpt-4.1",
    tools=[],
    system_prompt=eval_prompt,
    response_format=ToolStrategy(Similarity_Score)
)

# %%
from openai import OpenAI
from pydantic import BaseModel, Field

client = OpenAI()

class Similarity_Score(BaseModel):
    similarity_score: int = Field(description="Semantic similarity score between 1 and 10, where 1 means unrelated and 10 means identical.")

# NOTE: This is our evaluator
def compare_semantic_similarity(inputs: dict, reference_outputs: dict, outputs: dict):
    input_question = inputs["question"]
    reference_response = reference_outputs["output"]
    run_response = outputs["output"]

    agent= create_agent(
    model="gpt-4o-mini",
    tools=[],
    system_prompt=eval_prompt,
    response_format=ToolStrategy(Similarity_Score)
    )
    result=agent.invoke({"role": "user", "content": f"Question: {input_question}\n Reference Response: {reference_response}\n Run Response: {run_response}"})

    return {"score": result['structured_response'].similarity_score, "key": "similarity"}

# %%
# From Dataset Example
inputs = {
  "question": "What is the primary focus of the report for Tech Mahindra Limited in December 2025?"
}
reference_outputs = {
  "output": "you can carru forward 17 leaves"
}


# From Run
outputs = {
  "output": "The primary focus of the report for Tech Mahindra Limited in December 2025 is on HR Policies, Workforce Metrics, and Strategic AI Direction"
}

# %%
compare_semantic_similarity(inputs,reference_outputs,outputs)
# Out:
# {'score': 8, 'key': 'similarity'}

# %%
def compare_semantic_similarity_eval(reference_outputs: dict, outputs: dict):
    input_question = inputs["question"]
    reference_response = reference_outputs["output"]
    run_response = outputs["output"]

    agent= create_agent(
    model="gpt-4o-mini",
    tools=[],
    system_prompt=eval_prompt,
    response_format=ToolStrategy(Similarity_Score)
    )
    result=agent.invoke({"role": "user", "content": f"Question: {input_question}\n Reference Response: {reference_response}\n Run Response: {run_response}"})

    return {"score": result['structured_response'].similarity_score, "key": "similarity"}

# %% [markdown]
# # Evaluate

# %%
from langsmith import evaluate, Client

client = Client()
dataset_name = "techm_chatbot_golden_dataset"

def is_concise_enough(reference_outputs: dict, outputs: dict) -> dict:
    score = len(outputs["output"]) < 1.5 * len(reference_outputs["output"])
    return {"key": "is_concise", "score": int(score)}

def target_function(inputs: dict):
    return call_rag_chain(inputs["question"])

evaluate(
    target_function,
    data=dataset_name,
    evaluators=[is_concise_enough,compare_semantic_similarity_eval],
    experiment_prefix="gpt-4o-mini"
)
# Out:
# View the evaluation results for experiment: 'gpt-4o-mini-0b19f311' at:
# https://smith.langchain.com/o/b14e6248-7eea-4871-b9cf-55af6d804596/datasets/5b2bdb15-bd58-4db6-8c63-381a9f034a91/compare?selectedSessions=b6c15fb2-f093-44f7-a023-639502dd5f04
# 0it [00:00, ?it/s]
# Q: What is the title of the report discussed in the context?
# A: The title of the report discussed in the context is "Tech Mahindra: Comprehensive Report".
# Q: What are the three topics covered in the context provided?
# A: The three topics covered in the context provided are:
#
# 1. Key AI Technologies & Frameworks
# 2. Industry Focus Areas
# 3. Challenges & Opportunities
# Q: What section of the document contains information about leave policy and employee benefits?
# A: Section 1: Leave Policy & Employee Benefits
# Q: What is the number of professionals employed by Tech Mahindra, as mentioned in the report?
# A: The report mentions that Tech Mahindra has 150,000+ professionals.
# Q: What is the focus of Tech Mahindra Limited's report dated December 2025?
# A: The focus of Tech Mahindra Limited's report dated December 2025 is HR Policies, Workforce Metrics, and Strategic AI Direction.
# Q: What is the name of the initiative mentioned in the AI Strategy & Future Roadmap that focuses on delivering AI effectively?
# A: The name of the initiative is "AI Delivered Right."
# Q: What type of leave is described in section 1.1?
# A: The type of leave described in section 1.1 is Earned Leave (Annual Leave).
# Q: What information does the context provide about current headcount, historical trends, and attrition rates?
# A: The context provides the following information:
#
# - It mentions "Current headcount, historical trends, and attrition rates" as topics covered, but does not specify the exact current headcount or detailed historical numbers.
# - It states that attrition has gradually increased from approximately 11% to 12.8%, reflecting competitive market conditions and employee mobility.
# - The attrition rate of 12.8% is still within the industry acceptable range of 10-15%.
#
# No specific numbers for current headcount or detailed historical workforce trends are provided in the context.
# Q: What is the main purpose of the Executive Summary?
# A: I don't have enough information.
# Q: What types of leave and work-life balance initiatives are included in the company's HR policies?
# A: The company's HR policies include a comprehensive leave policy with 35-40+ days of annual paid time off (PTO), excellent maternity/paternity benefits with 90+ days of paid leave, and work-life balance initiatives supported through flexible work arrangements and flexible policies.
# Q: What is the name of the initiative mentioned in the AI Strategy & Future Roadmap that focuses on delivering AI effectively?
# A: The name of the initiative mentioned in the AI Strategy & Future Roadmap that focuses on delivering AI effectively is "AI Delivered Right".
# Q: What is the total number of professionals employed by Tech Mahindra according to the report?
# A: According to the report, Tech Mahindra employs 150,000+ professionals.
# Q: What are the three topics covered in the context provided?
# A: The three topics covered in the context provided are:
# 1. Key AI Technologies & Frameworks
# 2. Industry Focus Areas
# 3. Challenges & Opportunities
# Q: What is the title of the report discussed in the context?
# A: The title of the report discussed in the context is "Tech Mahindra: Comprehensive Report".
# Q: What is the main purpose of the Executive Summary?
# A: I don't have enough information.
# Q: What is the primary focus of Tech Mahindra Limited's report dated December 2025?
# A: The primary focus of Tech Mahindra Limited's report dated December 2025 is HR Policies, Workforce Metrics, and Strategic AI Direction.
# Q: What information does the context provide about current headcount, historical trends, and attrition rates?
# A: The context provides the following information:
#
# - It mentions "Employee Count & Workforce Metrics – Current headcount, historical trends, and attrition rates," but does not specify the exact current headcount or detailed historical numbers.
# - It states that attrition has gradually increased from approximately 11% to 12.8%, reflecting competitive market conditions and employee mobility. This attrition rate is still within the industry acceptable range of 10-15%.
#
# No specific numbers for current headcount or detailed historical trends are provided in the context.
# Q: What types of leave and work-life balance initiatives are included in the company's HR policies?
# A: The company's HR policies include a comprehensive leave policy with 35-40+ days of annual paid time off (PTO), excellent maternity and paternity benefits with 90+ days of paid leave, and flexible work arrangements to support work-life balance. Work-life balance is further supported through flexible policies and specific initiatives.
# Q: What type of leave is described in section 1.1?
# A: The type of leave described in section 1.1 is Earned Leave (Annual Leave).
# Q: What section of the document contains information about leave policy and employee benefits?
# A: Section 1: Leave Policy & Employee Benefits
# Q: What is the primary focus of the report for Tech Mahindra Limited in December 2025?
# A: The primary focus of the report for Tech Mahindra Limited in December 2025 is HR Policies, Workforce Metrics, and Strategic AI Direction.
# Q: What type of leave is referred to as "Earned Leave"?
# A: Earned Leave is referred to as Annual Leave.
# Q: What is the primary focus of Tech Mahindra's business operations?
# A: Tech Mahindra is India's leading IT services and consulting company.
# Q: What types of leave are included in the HR policies?
# A: The types of leave included in the HR policies are:
#
# - Earned/Annual Leave
# - Advance Leave
# - Public Holidays
# - Optional Holiday (self-selected festival/birthday)
# - Maternity Leave
# - Paternity Leave
# - Comp Off (if worked on holidays)
# Q: how many leaves can we carry forward?
# A: Maximum 16 days can be carried to next calendar year.
# Q: What are the current headcount and attrition rates of the workforce?
# A: The current attrition rate is 12.8%. The current headcount is not specified in the provided context.
# Q: What is the name of the initiative focused on AI strategy and future roadmap?
# A: The name of the initiative focused on AI strategy and future roadmap is "AI Delivered Right."
# Q: What are the key components of the leave policy outlined in Section 1?
# A: The key components of the leave policy outlined in Section 1 include a comprehensive breakdown of earned leaves, maternity/paternity benefits, and work-life balance initiatives.
# Q: What is the employee count mentioned in the context?
# A: The employee count mentioned in the context is:
#
# - 119,343 employees as of March 31, 2025
# - 148,731 employees (full fiscal year average for FY'25)
# - 152,714 employees as of September 30, 2025 (Q2 FY'26)
# Q: What is the main purpose of the executive summary?
# A: I don't have enough information.
# Q: What is the number of professionals employed by Tech Mahindra?
# A: Tech Mahindra employs 150,000+ professionals.
# <ExperimentResults gpt-4o-mini-0b19f311>
